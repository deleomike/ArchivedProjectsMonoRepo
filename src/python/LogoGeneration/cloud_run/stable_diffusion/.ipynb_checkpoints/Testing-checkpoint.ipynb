# %%
# make sure you're logged in with `huggingface-cli login`
from torch import autocast
import torch
from diffusers import StableDiffusionPipeline
from fastapi import FastAPI

from settings import DEVICE
from request_schemas import GenerateRequest

# %%
pipe = StableDiffusionPipeline.from_pretrained(
    "nota-ai/bk-sdm-small",
    # "CompVis/stable-diffusion-v1-4", 
    use_auth_token=True
).to(DEVICE)
# Out:
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["id2label"]` will be overriden.
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["bos_token_id"]` will be overriden.
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["eos_token_id"]` will be overriden.

# %%
pipe.enable_attention_slicing()
pipe.safety_checker = None

# %%
prompt = "lips, long hair, looking at viewer, young, asian, jewelry, cleavage, necklace, large breasts, open mouth, pink hair, headphones, breast hold, large breasts, large breasts, ass, panties, white bra. a beautiful woman with giant breasts and a large ass riding a big cock in her vagina. While her stomach is filling with cum"
prompt = "((ultra realistic high definition RAW photograph of photo)) beautiful chinese female model,((((1girl)))),18-25 years old, 11th-13th century china, partially clothed, embarrassed facial expression, looking away at pov, pale skin, medium size boobs, detailed nipple, young pussy with pubic hair with best quality, ((visible detail clitoris)), traditional hairstyle, (A girl in reversecow position has sex with a boy:1.3),revcowgirl, 1man, ultra detailed, (photo realistic:1.37), very detailed faces, extremely delicate and beautiful, (light on face:1.2), (penis penetrating pussy) , testicles, window with mountain top background, editorial quality, camera: Nikon d850, focal length 100mm"
prompt = "pregnant belly, huge belly, skinny waist, inflating stomach, stomach bulging, \
        stomach filling with cum, large stomache, petite woman, pregnant belly, cum leaking, stomach inflation,\
        bloating, doggy style, looking at viewer, nikon, open mouth, orgasm, cum filled pussy, very detailed faces, \
        extremely delicate and beautiful, (light on face:1.2), (penis penetrating pussy) , testicles, \
        window with mountain top background, editorial quality, camera: Nikon d850, focal length 100mm"
neg_prompt = "badhandv4 bhands CyberRealistic_Negative-neg easynegative facev2 fcNeg ng_deepnegative_v1_75t, (((2 or more females))), (((2 or more male)))"

if DEVICE != "mps":
    with autocast(DEVICE):
        _ = pipe(prompt, num_inference_steps=1)
        images = pipe(prompt)["sample"] 
else:
    pipe(prompt, negative_prompt=neg_prompt, num_inference_steps=1)
    pipe(prompt, negative_prompt=neg_prompt, num_inference_steps=1)
    images = pipe(prompt, num_inference_steps=30, negative_prompt=neg_prompt, num_images_per_prompt=3)
# Out:
# ...
#   0%|          | 0/30 [00:00<?, ?it/s]

# %%
for idx, image in enumerate(images.images): 

    display(image)

    # image.save(f"astronaut_rides_horse_{idx}.png")
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>
# <PIL.Image.Image image mode=RGB size=512x512>
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
images
# Out:
# StableDiffusionPipelineOutput(images=[<PIL.Image.Image image mode=RGB size=512x512 at 0x105F6C8B0>], nsfw_content_detected=None)

# %%
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>
